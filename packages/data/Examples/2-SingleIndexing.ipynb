# %% [markdown]
# # Single Indexing

# %%
import pyearthtools.data

# %% [markdown]
# ## Variables

# %%
var = 'tcwv'

# %% [markdown]
# ## Advanced Single Indexing
# In addition to retrieving a single timestep, when calling a DataIndex, if the time is not fully defined, as in that the data is hourly but the time provided is merely day, all timesteps which could fit that criterion are automatically loaded.
# In this call an aggregation function can be provided, which will also be run.
#
# First setting up the ERA5 DataIndex

# %%
era5 = pyearthtools.data.archive.ERA5(var, level = 'single')

# %% [markdown]
# There are a variety of ways to now index into this DataIndex. We could specify a particular time.

# %%
era5('2021-01-01T01')
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 1, latitude: 721, longitude: 1440)
# Coordinates:
#   * longitude  (longitude) float32 -180.0 -179.8 -179.5 ... 179.2 179.5 179.8
#   * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#   * time       (time) datetime64[ns] 2021-01-01T01:00:00
# Data variables:
#     tcwv       (time, latitude, longitude) float32 4.826 4.826 ... 0.5562 0.5562

# %% [markdown]
# Retrieving all data on a certain day.

# %%
era5('2021-01-01')
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 24, latitude: 721, longitude: 1440)
# Coordinates:
#   * longitude  (longitude) float32 -180.0 -179.8 -179.5 ... 179.2 179.5 179.8
#   * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#   * time       (time) datetime64[ns] 2021-01-01 ... 2021-01-01T23:00:00
# Data variables:
#     tcwv       (time, latitude, longitude) float32 dask.array<chunksize=(24, 253, 506), meta=np.ndarray>

# %% [markdown]
# Providing an aggreagation function to find the 'mean'

# %%
era5('2021-01-01', aggregation = 'mean')
# Out:
# <xarray.Dataset>
# Dimensions:    (latitude: 721, longitude: 1440)
# Coordinates:
#   * longitude  (longitude) float32 -180.0 -179.8 -179.5 ... 179.2 179.5 179.8
#   * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
# Data variables:
#     tcwv       (latitude, longitude) float32 dask.array<chunksize=(253, 506), meta=np.ndarray>

# %% [markdown]
# ## Another Data source

# %%
sat = pyearthtools.data.archive.satellite()

# %%
sat('2021-01-01T01')
# Out:
# <xarray.Dataset>
# Dimensions:                     (time: 6, latitude: 1726, longitude: 2214)
# Coordinates:
#   * time                        (time) datetime64[ns] 2021-01-01T01:00:00 ......
#   * latitude                    (latitude) float32 -44.5 -44.48 ... -10.02 -10.0
#   * longitude                   (longitude) float32 112.0 112.0 ... 156.2 156.3
# Data variables:
#     crs                         (time) int32 -2147483647 ... -2147483647
#     surface_global_irradiance   (time, latitude, longitude) float64 dask.array<chunksize=(1, 1726, 2214), meta=np.ndarray>
#     direct_normal_irradiance    (time, latitude, longitude) float64 dask.array<chunksize=(1, 1726, 2214), meta=np.ndarray>
#     surface_diffuse_irradiance  (time, latitude, longitude) float64 dask.array<chunksize=(1, 1726, 2214), meta=np.ndarray>
#     quality_mask                (time, latitude, longitude) float64 dask.array<chunksize=(1, 1726, 2214), meta=np.ndarray>
#     cloud_type                  (time, latitude, longitude) float32 dask.array<chunksize=(1, 1726, 2214), meta=np.ndarray>
#     cloud_optical_depth         (time, latitude, longitude) float64 dask.array<chunksize=(1, 1726, 2214), meta=np.ndarray>
#     solar_elevation             (time, latitude, longitude) float64 dask.array<chunksize=(1, 1726, 2214), meta=np.ndarray>
#     solar_azimuth               (time, latitude, longitude) float64 dask.array<chunksize=(1, 1726, 2214), meta=np.ndarray>
#     julian_date                 (time, latitude, longitude) float64 dask.array<chunksize=(1, 1726, 2214), meta=np.ndarray>
# Attributes: (12/57)
#     Conventions:                      CF-1.7
#     Metadata_Conventions:             Unidata Dataset Discovery v1.0
#     acknowledgment:                   The following acknowledgement is requir...
#     cdm_data_type:                    grid
#     comment:                          Solar radiation data derived from satel...
#     contributor_name:                 Mines ParisTech; Commonwealth of Austra...
#     ...                               ...
#     bias_correction_applied_meaning:  0: not applied; 1:applied
#     quality:                          0
#     quality_meaning:                  0: no_known_issues 1: known_issue
#     history:                          heliosat-4; post_process_p1s.py
#     references:                       Poulsen C., Majewski L. J. (2022) Gridd...
#     project:                          Gridded Solar Observations
